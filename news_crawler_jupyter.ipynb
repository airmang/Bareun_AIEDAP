# %% [markdown]
# # 네이버 뉴스 API를 활용한 데이터 수집 실습
#
# ## 들어가며
# 이 실습에서는 네이버 뉴스 검색 API를 활용하여 실시간으로 뉴스 데이터를 수집하고 분석하는 방법을 배웁니다.
# 데이터 수집의 기초부터 데이터 정제, 저장, 그리고 기본적인 분석까지의 전 과정을 파이썬으로 구현해보면서
# 실제 데이터 과학 프로젝트의 흐름을 경험해 볼 수 있습니다.
#
# ## 학습 목표
# 1. **API의 개념과 활용**: 외부 서비스 API를 통한 데이터 수집 방법 이해
# 2. **HTTP 통신 기초**: 요청과 응답 구조, 헤더와 파라미터 활용법 습득
# 3. **JSON 데이터 처리**: JSON 형식의 데이터를 파싱하고 활용하는 방법 학습
# 4. **HTML 처리 기술**: Beautiful Soup을 활용한 HTML 태그 제거 및 텍스트 추출
# 5. **데이터 저장**: 수집한 데이터를 엑셀 파일로 저장하는 다양한 방법 습득
# 6. **데이터 분석 기초**: 판다스를 활용한 기본 데이터 분석 및 시각화 경험
#
# ## 사전 준비사항
# - Python 기본 문법에 대한 이해
# - Jupyter Notebook 사용법 숙지
# - 필요 라이브러리 설치 (`requests`, `beautifulsoup4`, `pandas`, `openpyxl`)
#
# 이 실습을 마치면 여러분은 실제 데이터를 수집하고 처리하는 능력을 갖추게 될 것입니다.
# 이러한 기술은 데이터 분석, 머신러닝, 그리고 자연어 처리 분야에서 매우 중요한 기초가 됩니다.

# %% [markdown]
# ## 1. 필요한 라이브러리 임포트
#
# 데이터 수집과 처리를 위해 다음과 같은 라이브러리들을 사용합니다:
#
# - **requests**: 웹 서버에 HTTP 요청을 보내고 응답을 받는 기능을 제공합니다.
# - **json**: JSON 형식의 데이터를 파이썬 객체로 변환하거나, 파이썬 객체를 JSON으로 변환하는 기능을 제공합니다.
# - **BeautifulSoup**: HTML 또는 XML 문서를 파싱하고 데이터를 추출하는 기능을 제공합니다.
# - **pandas**: 데이터 분석과 조작을 위한 고성능 도구를 제공합니다.
# - **re**: 정규표현식을 사용하여 텍스트를 처리하는 기능을 제공합니다.
# - **openpyxl**: 엑셀 파일(.xlsx)을 읽고 쓰는 기능을 제공합니다.
#
# 만약 이러한 라이브러리가 설치되어 있지 않다면, 다음과 같이 설치할 수 있습니다:
# ```
# pip install requests beautifulsoup4 pandas openpyxl
# ```

# %%
# 필요한 라이브러리 임포트
import requests  # HTTP 요청을 보내기 위한 라이브러리
import json  # JSON 데이터 처리를 위한 라이브러리
from bs4 import BeautifulSoup  # HTML 파싱을 위한 라이브러리
import pandas as pd  # 데이터 처리를 위한 라이브러리
import re  # 정규표현식을 사용하기 위한 라이브러리
import openpyxl  # 엑셀 파일 처리를 위한 라이브러리

# %% [markdown]
# ## 2. API 인증 정보 설정
#
# 네이버에서는 개발자들에게 다양한 API 서비스를 제공하고 있습니다. 이러한 API를 사용하기 위해서는 인증 정보가 필요합니다.
#
# ### 네이버 API 인증 정보 발급 방법
# 1. 네이버 개발자 센터(https://developers.naver.com)에 접속합니다.
# 2. 회원가입 및 로그인 후 "애플리케이션 등록" 메뉴를 선택합니다.
# 3. "애플리케이션 이름"과 사용할 API를 선택하고 필요한 정보를 입력합니다.
# 4. 등록 완료 후 "Client ID"와 "Client Secret"을 발급받습니다.
#
# ### 중요한 보안 사항
# * API 키는 개인 정보와 같이 중요한 보안 정보입니다.
# * 실제 프로젝트에서는 코드에 직접 입력하지 말고, 환경 변수나 별도의 설정 파일에서 불러오는 것이 좋습니다.
# * Git과 같은 버전 관리 시스템에 API 키를 포함하지 않도록 주의해야 합니다.
#
# **참고**: 이 실습에서는 제공된 API 키를 사용하지만, 실제 프로젝트에서는 본인의 API 키를 발급받아 사용하는 것이 좋습니다.

# %%
# 네이버 개발자 센터에서 발급받은 API 인증 정보
client_id = "yR8aViAqV5NyEjZpfo74"  # 네이버 API 클라이언트 ID
client_secret = "SQ_PTt2epk"  # 네이버 API 클라이언트 시크릿

# %% [markdown]
# ## 3. 검색어 입력 및 API 요청 설정
#
# API를 통해 검색 결과를 가져오기 위해 사용자로부터 검색어를 입력받고, API 요청에 필요한 URL과 헤더를 설정합니다.
#
# ### 주요 개념
# - **URL 파라미터**: API 요청시 검색어(`query`), 결과 개수(`display`) 등을 URL에 포함시켜 전달합니다.
# - **요청 헤더**: API 인증을 위해 클라이언트 ID와 시크릿 키를 헤더에 포함시킵니다.
# - **f-string**: 파이썬 3.6 이상에서 제공하는 문자열 포맷팅 방식으로, 변수를 문자열 안에 쉽게 삽입할 수 있습니다.
#
# ### 네이버 API 매개변수
# - `query`: 검색어 (필수)
# - `display`: 검색 결과 출력 건수 (기본값: 10, 최대: 100)
# - `start`: 검색 시작 위치 (기본값: 1, 최대: 1000)
# - `sort`: 정렬 옵션 (`sim`: 유사도순, `date`: 날짜순)
#
# 다음 코드를 통해 사용자로부터 검색어를 입력받고 API 요청을 준비합니다.

# %%
# 사용자로부터 검색어 입력 받기
query = input("검색할 키워드를 입력하세요: ")  # 검색할 키워드 입력
display = 100  # 한 번에 가져올 검색 결과 개수 (최대 100개까지 설정 가능)

# 네이버 뉴스 검색 API URL 생성
url = f"https://openapi.naver.com/v1/search/news.json?query={query}&display={display}"

# API 요청 헤더 설정
headers = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret,
}

# %% [markdown]
# ## 4. API 요청 및 응답 처리
#
# 설정한 URL과 헤더를 사용하여 API 요청을 보내고, 응답을 처리합니다.
#
# ### 코드 설명
# - `requests.get()`: HTTP GET 요청을 보내는 함수입니다. URL과 헤더 정보를 인자로 전달합니다.
# - `response.status_code`: HTTP 응답 상태 코드로, 요청이 성공했는지 여부를 확인할 수 있습니다.
#   - 200: 요청 성공
#   - 400: 잘못된 요청
#   - 401: 인증 실패
#   - 404: 리소스를 찾을 수 없음
#   - 500: 서버 내부 오류
# - `response.json()`: 응답 데이터를 JSON 형식으로 파싱합니다.
#
# ### 예외 처리
# API 요청 시에는 항상 응답 상태 코드를 확인하여 요청이 성공적으로 처리되었는지 확인하는 것이 중요합니다. 이를 통해 오류 발생 시 적절한 처리를 할 수 있습니다.

# %%
# API 요청 보내기
response = requests.get(url, headers=headers)

# 응답 상태 코드 확인
print(f"응답 상태 코드: {response.status_code}")

# 응답이 성공적인 경우 (상태 코드 200)
if response.status_code == 200:
    # JSON 응답 데이터 파싱
    news_data = response.json()
    
    # 검색 결과 항목 수 출력
    if 'items' in news_data:
        print(f"총 {len(news_data['items'])}개의 뉴스 기사를 찾았습니다.")
    else:
        print("검색 결과가 없습니다.")
else:
    print(f"API 요청 실패: {response.status_code}")
# Out:
# 응답 상태 코드: 200
# 총 100개의 뉴스 기사를 찾았습니다.

# %% [markdown]
# ## 5. 검색 결과 데이터 확인
#
# API 응답으로 받은 JSON 데이터의 구조를 확인합니다. JSON(JavaScript Object Notation)은 데이터를 교환하는 데 널리 사용되는 형식입니다.
#
# ### JSON 데이터 구조 이해하기
# 네이버 뉴스 API는 다음과 같은 구조의 JSON 데이터를 반환합니다:
# - `lastBuildDate`: 검색 결과 생성 시간
# - `total`: 검색 결과 총 개수
# - `start`: 검색 결과 시작 위치
# - `display`: 한 번에 표시되는 검색 결과 개수
# - `items`: 뉴스 기사 항목 배열
#   - `title`: 뉴스 제목
#   - `originallink`: 뉴스 원본 링크
#   - `link`: 네이버 뉴스 링크
#   - `description`: 뉴스 내용 요약
#   - `pubDate`: 발행 날짜
#
# 아래 코드에서는 `json.dumps()` 함수를 사용하여 첫 번째 뉴스 항목을 보기 좋게 출력합니다. `indent` 파라미터는 들여쓰기를, `ensure_ascii=False`는 한글이 깨지지 않도록 합니다.

# %%
# API 응답 데이터 구조 확인 (첫 번째 항목만)
if response.status_code == 200 and 'items' in news_data and len(news_data['items']) > 0:
    print("첫 번째 뉴스 항목 데이터:")
    print(json.dumps(news_data['items'][0], indent=2, ensure_ascii=False))
else:
    print("데이터를 표시할 수 없습니다.")
# Out:
# 첫 번째 뉴스 항목 데이터:
# {
#   "title": "[채희창칼럼] 날개 없이 추락하는 <b>교권</b>",
#   "originallink": "http://www.segye.com/newsView/20250519514994?OutUrl=naver",
#   "link": "https://n.news.naver.com/mnews/article/022/0004036830?sid=110",
#   "description": "늘어 <b>교권</b> 보호 없인 국가 발전 어려워 지난달 28일 부산의 한 초등학교에서 5학년 A군이 여교사를 폭행하는... 정신적 충격을 받은 B교사가 <b>교권</b>보호위원회를 열려고 하자 A군의 부모는 되레 B교사를 아동학대 혐의로... ",
#   "pubDate": "Mon, 19 May 2025 23:30:00 +0900"
# }

# %% [markdown]
# ## 6. 검색 결과 처리 및 엑셀 파일 저장
#
# 검색 결과에서 제목과 본문을 추출하고, HTML 태그를 제거한 후 엑셀 파일로 저장합니다.
#
# ### 데이터 정제 과정
# 1. **HTML 강조 태그 제거**: 네이버 검색 API는 검색어와 일치하는 부분을 `<b>` 태그로 강조합니다. 이 태그를 제거하여 텍스트만 추출합니다.
# 2. **HTML 태그 제거**: BeautifulSoup 라이브러리를 사용하여 남아있는 HTML 태그를 제거하고 순수 텍스트를 추출합니다.
#
# ### 엑셀 파일 저장 과정
# 1. **워크북 생성**: openpyxl을 사용하여 새 엑셀 파일을 생성합니다.
# 2. **데이터 추가**: 추출한 제목과 본문을 행으로 추가합니다.
# 3. **파일 저장**: 검색어를 파일명에 포함하여 저장합니다.
#
# 이 과정을 통해 웹에서 가져온 데이터를 구조화된 형태로 저장하고 추후 분석에 활용할 수 있습니다.

# %%
if response.status_code == 200:
    # Openpyxl을 사용하여 새 워크북 생성
    wb = openpyxl.Workbook()
    ws = wb.active
    ws.title = "네이버 뉴스 검색 결과"
    
    # 열 제목 추가
    ws.append(["제목", "본문"])
    
    if 'items' in news_data:
        # 검색 결과가 있는 경우 처리 시작
        for item in news_data['items']:
            # HTML 강조 태그(<b></b>)를 제거하여 제목과 본문 텍스트 추출
            title = item['title'].replace("<b>", "").replace("</b>", "")
            content = item['description'].replace("<b>", "").replace("</b>", "")
            
            # BeautifulSoup을 사용하여 남아있는 HTML 태그를 제거하고 순수 텍스트 추출
            clean_title = BeautifulSoup(title, "html.parser").text
            clean_content = BeautifulSoup(content, "html.parser").text
            
            # 추출한 제목과 본문을 콘솔에 출력
            print(f"제목: {clean_title}")
            print(f"본문: {clean_content}")
            print("-" * 50)
            
            # 추출한 제목과 본문을 엑셀 워크시트에 추가
            ws.append([clean_title, clean_content])
        
        # 엑셀 파일 저장
        file_name = f"{query}_news.xlsx"
        wb.save(file_name)
        print(f"'{file_name}' 파일에 저장되었습니다.")
    else:
        # 검색 결과가 없는 경우 메시지 출력
        print("검색 결과가 없습니다.")
else:
    # API 요청이 실패한 경우 오류 코드와 함께 메시지 출력
    print("API 요청 실패:", response.status_code)
# Out:
# 제목: [채희창칼럼] 날개 없이 추락하는 교권
# 본문: 늘어 교권 보호 없인 국가 발전 어려워 지난달 28일 부산의 한 초등학교에서 5학년 A군이 여교사를 폭행하는... 정신적 충격을 받은 B교사가 교권보호위원회를 열려고 하자 A군의 부모는 되레 B교사를 아동학대 혐의로...
# --------------------------------------------------
# 제목: 이재명 후보 '미래교육자치위원회' 공식 출범… 200명 넘는 전문가 집결
# 본문: 총장), 교권보호특위(김성근 전 교육부 학교혁신지원실장), 학부모소통특위(김유임 전 대통령실... 학생 건강·안전, 교권, 학부모, 지역거버넌스, 교육회복, 특수교육 이외에도 학생건강안전특위는 대학 내 학생상담센터...
# --------------------------------------------------
# 제목: [교육논단] 교육 공약을 살펴보다
# 본문: 각종 제도와 장치를 통해서 교권과 학습권을 강화하여 교육 회복을 여는 것. 기초 학력 교과 교육을... 교원지위법에 대한 개정 및 교육활동 중에서 발생하는 안전사고에 대한 교원의 책임을 면책 등 교권 향상에 관한...
# --------------------------------------------------
# 제목: [앵커 브리핑] 갈수록 추락하는 교권···공교육 회복은 어떻게?
# 본문: 2023년 서이초 사건 당시 전국의 교사들이 거리로 나와 ‘공교육 멈춤의 날’ 집회가 열렸고 '교권 보호 5법'이 국회를 통과했습니다. 교권 보호 5법의 핵심은 학생 분리 조치 시행과 학교 민원 대응팀 구성입니다....
# --------------------------------------------------
# 제목: 비참한 교권, 누가 이렇게 만들었나
# 본문: 교권은 오랫동안 학생과 학부모, 그리고 그 잘난 정치인들에게 셀 수도 없을 만큼 차였다. 더 이상 떨어질... 이유로는 교권 침해 및 과도한 민원이 48.3%로 가장 많았다. '1년간 교권 침해를 당한 경험이 있는지'에 대한...
# --------------------------------------------------
# 제목: [대담한K] ‘흔들리는 교단’…교권 침해 실태와 해법은?
# 본문:
# --------------------------------------------------
# 제목: [시시각각]교육을 표만으로 계산해서는 안 된다
# 본문: 주요 대선 후보와 정당들이 속속 '장밋빛 청사진'을 공약으로 내놓고 있지만, 학령인구 감소와 의대증원 문제, 교권 침해, 사교육 심화 등 산적한 교육 현안은 대선 이슈의 중심에서 비껴가는 모양새다. 더불어민주당 이재명...
# --------------------------------------------------
# 제목: 교계, 정치권에 기독사학 자율·차금법 저지 요청
# 본문: 향해 “편향된 이념적 인권을 앞세워 언론, 표현, 학문, 종교, 양심, 사상의 자유를 무력화시킨다”고 우려했다. 또 교권과 부모의 권리를 짓밟고, 남녀 구별을 해체할 것이라는 이유를 들어 차금법 제정 반대 입장을 밝혔다.
# --------------------------------------------------
# 제목: [이슈브리핑] ‘포항지진 손배소’ 항소심서 뒤집혀 외
# 본문: ['KBS 뉴스7 대구·경북' 지난 13일 보도화면 : "교사를 상대로 한 욕설이나 폭행, 고의적인 수업 방해 등으로 교권이 침해받았을 때 열리는 교권보호위원회, 교보위가 지난해 4천 2백여 건 열린 것으로 집계됐습니다. 하루...
# --------------------------------------------------
# 제목: 경북교총 ‘한마음체육대회’ 성료
# 본문: 의식으로 교권을 바로 세워나가는 증폭제가 되기를 바란다”고 말했다. 임종식 교육감은 “경북교총의 창립 80주년을 축하하며 승부를 떠나 스포츠 활동을 통해 교육가족 구성원이 함께 소통하고 교육 현장의 스트레스...
# --------------------------------------------------
# 제목: 보건학문&인권연구소 "진보좌파 혁신교육 심판 위해 김문수 지지"
# 본문: 하향평준화와 교권의 파괴등 공교육을 싸그리 망치고 있었다"고 규정했다. 그러면서 "대한민국 교육부 예산... 무너진 교권을 살리기 원하는 교사들은 당연히 김문수 후보를 지지해야 한다"고 주장했다. 아울러 "지난...
# --------------------------------------------------
# 제목: 기독교계, 대선 앞두고 ‘차별금지법과 포괄적 성교육 반대 집회’
# 본문: 편향된 이념으로 자유 무력화시켜 성착취와 동성애·성전환 급증할 것 교권 붕괴시키고 부모 권리 짓밟아... 된다 ▲교권을 붕괴시키고 부모의 권리를 짓밟는다 ▲성별 개념을 바꿔 남자와 여자의 구별을 해체한다...
# --------------------------------------------------
# 제목: [사설] 교원 사기 진작과 지위 향상을 위한 대책 시급
# 본문: 교사들은 고된 행정 업무에 시달리거나 교권 침해 등으로 어려움을 겪기 일쑤다. 이들은 학생을 제대로... 교권 관련 문항에선 전체의 56.3%가 최근 1년간 학생에게 교권 침해를 당한 적이 있다고 답했다. 이 조사에는...
# --------------------------------------------------
# 제목: 안양과천교육지원청, 10월까지 '교원 힐링성장 프로그램' 운영
# 본문: 다양한 힐링 프로그램을 지속 운영해 나가겠다”고 말했다. [ 경기신문 = 송경식 기자 ] 안양과천교육지원청 교권보호지원센터가 16일 교원을 대상으로 힐링공감 콘서트를 하고 있다.(사진=안양과천교육지원청 제공)
# --------------------------------------------------
# 제목: [단독]교사에 협박편지 보낸 학부모, 오히려 교사에 명예훼손 소송 제기
# 본문: ●서부지법 “학부모 협박, 공무집행방해 등 인정” 학교 교권보호위원회는 2023년 12월 학부모의 교권침해 행위를 인정해 교육청의 고발 및 재발 방지 대책 마련, 심리상담 지원, 치료 지원, 민사소송 지원 및 협조를...
# --------------------------------------------------
# 제목: 보성 홍지중고 파행 반발 확산 "전남도교육청 미온적 태도" 질타
# 본문: 민주노총 전남중소사업장연대노조는 15일 전남도교육청 앞에서 기자회견을 열어 "학력 인정 홍지중고등학교 학생과 교사들은 이사장의 상습적인 임금체불과 악의적인 부당노동행위로 교사들 교권이 땅에 떨어지고...
# --------------------------------------------------
# 제목: <이슈점검>땅바닥으로 떨어진 교권…下 교육계 제언
# 본문: 전문가들은 날이 갈수록 심해지는 교권침해 문제를 해결하고, 교단이 바로 서기 위해서는 교사들의 정당한 교육활동을 지원할 수 있는 제도적 기반이 마련돼야 한다고 입을 모았다. 교권 5법 개정·시행으로 정당한 교육...
# --------------------------------------------------
# 제목: [이로운주목]정근식 '대입 개편' 제안, 이재명 '교육 공공성' 공약…공...
# 본문: 지난 15일 스승의 날에 맞춰 발표한 교육공약에서는 유아·초등교육의 국가 책임 강화와 교권 보호제도... △기초학력 보장 △특수교육·다문화 학생 맞춤 지원 확대 △학생·교원 마음 건강 지원 강화 △교권보호 강화...
# --------------------------------------------------
# 제목: 대선 후보들 '교권보호' 공통 공약
# 본문: 공약으로 교권 보호와 공교육·돌봄 강화, 고등교육(대학) 혁신, 평생교육 확대 등을 제시했다. 19일 본보가... 확대 △교권 보호 제도 체계화가 있다. 이 후보는 먼저 유아교육·보육비를 5세부터 단계적으로 확대하고...
# --------------------------------------------------
# 제목: 대전지역 노조, 교원·공무원, 장애인 단체 '이재명 후보' 지지 선언
# 본문: 이호범 단장은 "그동안 공무원의 정치 기본권이 제약되어 있어 목소리를 내지 못했다"라며 "120만~130만 명에 달하는 교원과 공무원의 목소리가 매번 선거에서 제대로 반영되지 못해 교권 및 공무원 처우에 문제점들이...
# --------------------------------------------------
# 제목: 포항중학교, 교육활동 보호주간 맞아 풍성한 행사 펼쳐
# 본문: ▲ 포항중학교 교직원, 학생, 학부모가 함께 교권의 소중함을 되새기는 캠페인을 펼치고 있다. 포항중학교... 맞아 교권 존중 및 행복한 학교 문화 조성을 위한 다양한 행사를 진행했다. 특히 지난 15일에는 교직원과 학생회...
# --------------------------------------------------
# 제목: 경남교총 '제3회 남교원동아리배구대회' 성료
# 본문: 또한 대회를 넘어 교권을 확립하고 교원들의 자긍심을 회복하자는 의지를 다지는 대회의 의미를 가진다. 교사가 행복해야 교육도 행복하다. 녹록지 않은 학교현장이지만 위로와 격려의 행복한 대회가 되길 바란다"고...
# --------------------------------------------------
# 제목: 교권보장·교육환경 개선 "보다 더 꼼꼼하게"
# 본문: 특히 교권침해로부터 안전하게 보호받지 못하고 있다는 응답이 79.61%, 안전한 교육환경에서 학생을 가르칠... 해마다 되풀이되는 교권 침해 예방과 회복을 위한 실질적 제도 마련, 교사의 수업권·평가권 보장을 위한...
# --------------------------------------------------
# 제목: 대선후보 교육공약 비교⋯ 무상교육·교권보호·지역균형에 방점
# 본문: 세 후보는 모두 무상교육과 교권강화, 지방대 경쟁력 향상을 약속했다. 이재명, '보편적 교육복지'와 '지역... 또한, 교권 보호 제도 강화, 근무시간 외 정치활동의 자유 보장, 민원 처리 시스템의 체계화, 등 교권을 강화하는...
# --------------------------------------------------
# 제목: “누굴 뽑나”…대선 후보 공약 등 담긴 ‘선거공보’ 전국 모든 세대 ...
# 본문: 슬로건 ‘압도적으로 새로운 대한민국’을 앞세운 그는 ▲효율적 중앙정부 ▲책임 있는 지방분권 ▲세종 행정수도 완성 ▲교권 회복 ▲연구자 생활 안정 ▲의료인 자율성 강화 ▲청년 기회자금 제공 ▲미래세대 연금...
# --------------------------------------------------
# 제목: 인천교사노조, 온라인에서의 교사 명예휘손 건 대한 제도적 대응 마련 ...
# 본문: 인천교사노조는 이날 "피해 교사가 정보통신망법상 명예훼손 혐의로 관련 학부모를 고소한 것에 대해 경찰은 '증거불충분'으로 불송치 결정을 내렸다"며 "이는 교육지원청 교권보호위원회 및 아동학대 무고 결정과...
# --------------------------------------------------
# 제목: 인천 교사 명예훼손 사건, 경찰 증거불충분으로 불송치 결정 논란
# 본문: 보호와 교권 회복의 필요성이 대두되고 있다. 인천교사노조는 이 사건을 계기로 교사의 교육활동 보호와 명예... 이에 대해 지역 교육지원청 교권보호위원회는 해당 게시 행위를 ‘교육활동 침해 및 명예훼손’으로...
# --------------------------------------------------
# 제목: AI가 읽어주는 오늘의 사설-비참한 교권, 누가 이렇게 만들었나
# 본문: 기호일보 - 아침을 여는 신문, KIHOILBO
# --------------------------------------------------
# 제목: [샬롬나비 스승의 날 논평] 선생님들의 교단은 버겁다
# 본문: 대한민국 교육시스템은 교권이 무너진 사회이지만 스승 존경으로 교육계의 신선한 바람이 불게 하자 학생 인권에 못지 않게 선생님이 소신을 가지고 교육할 수 있도록 교권을 세우고 보호하자 매년마다 돌아오는 스승의...
# --------------------------------------------------
# 제목: “불법 녹음” 말고 길이 없다면, 그건 누구의 책임인가 [왜냐면]
# 본문: 문제는 교사의 교권이 아니다. 진짜 위기는 교사와 아동 모두를 지킬 수 없는 교육 시스템이다. 특수교육 현장은 가장 많은 돌봄이 필요한 공간이지만, 가장 적은 감시가 이루어지는 곳이기도 하다. 교사의 감정노동에 대한...
# --------------------------------------------------
# 제목: 수원청소년비행예방센터, 수원중부서·경기대와 '3자 협약' 맞손
# 본문: 청소년비행예방센터는 지역사회 위기 청소년들에게 학교폭력 및 교권침해 예방교육, 도박 및 디지털 성범죄 예방교육, 가족 캠프, 체험 활동, 진로 교육 등 다양한 교육 기회를 제공하는 청소년 비행예방 전문교육기관으로...
# --------------------------------------------------
# 제목: [칼럼]'관인기소'의 지혜, 인성교육에 답이 있다
# 본문: 학교폭력, 교권 추락, 부모의 입시비리, 대입 브로커까지. 오늘날 교육현장에서 벌어지는 일들은 단지 제도의... 교권 회복은 단순한 보호 조치가 아니라, 교육의 질을 되살리는 기초다. 평가 방식도 바뀌어야 한다. 지금의...
# --------------------------------------------------
# 제목: [토크ON] ① 무너지는 공교육···교육 현장 분위기는?
# 본문: 서이초 사건이 발생한 지 2년이 지났지만, 각종 교권 침해는 여전히 발생하고 있습니다. 수업 방해와 악성 민원, 무고성 아동학대 고소 등 여러 교권 침해로 공교육 부실 논란 등이 이어지면서 교원·학생·학부모의 우려가...
# --------------------------------------------------
# 제목: ‘세이브코리아와 함께했던 사람들’, 김문수 후보 지지 선언
# 본문: 교권을 무너뜨리고 다음세대를 망가뜨리는 학생인권조례도 반대했습니다. 노동자들과 한센인 등을 비롯한 우리 사회의 약자들을 위해 평생을 헌신했을 뿐 아니라, 우리나라에서 최초로 북한인권법을 발의하고 북한...
# --------------------------------------------------
# 제목: '교원 명예훼손' 인천 초교 학부모 불송치 "경찰, 재수사해야"
# 본문: 해당 학교가 속한 인천시교육청 산하 교육지원청 교권보호위원회는 해당 게시 행위를 교육활동 침해와 명예훼손이라고 판단하고 A씨에게 특별교육 조치를 결정했다. 또한 경찰은 학부모 A씨가 교사 B씨에게 제기한...
# --------------------------------------------------
# 제목: 경북교총 교육가족 체육대회 성료
# 본문: 김준철 회장은 “교총 회원들의 성원에 힘입어 경북교총이 80년의 역사와 전통을 이어올 수 있었다”며 감사 인사를 전하고 “이번 체육대회가 공동체 의식을 발현하고 교권을 바로 세워나가는 증폭재가 되길...
# --------------------------------------------------
# 제목: 예산 예목유, 교육활동 보호 주간 '감사의 날' 실시
# 본문: 이번 행사는 교권을 존중하는 문화를 조성하고, 교사와 유아 간의 신뢰를 형성하여 긍정적인 교육 관계... 마지막 날인 16일에는 유아와 교직원들이 함께 교권 보호의 메시지를 담은 샌드아트 공연 '선생님을 존중해요'를...
# --------------------------------------------------
# 제목: [교육 소식] 안양과천교육지원청, 교원 힐링 공감 콘서트
# 본문: ▲ 안양과천교육지원청 교권보호지원센터가 마련한 힐링 공감 콘서트에서 교원들이 음악에 맞춰 박수를 치고 있다./사진제공=안양과천교육지원청 안양과천교육지원청은 오는 10월 말까지 '교원 힐링 성장 프로그램'을...
# --------------------------------------------------
# 제목: 청송여자중·고등학교, 학생 백일장과 미술 행사 개최
# 본문: 한글을 창제하여 온 백성에게 가르침을 준 세종대왕의 탄신에서 따온 스승의날은 교권 존중과 스승 공경의 사회적 풍토를 조성하고 교원의 사기 진작과 사회적 지위 향상을 위하여 지정된 날이다. 스승의날 모든 행사가...
# --------------------------------------------------
# 제목: 누구를 위한스승의 날? "차라리 없애자"
# 본문: 스승을 존경하는 마음과 교권에 대한 인식 제고를 위해 만들어진 스승의 날. 하지만 부산지역 교사 3명 중... 가장 큰 이유는 교권침해와 과도한 민원이었고, 낮은 급여도 뒤를 이었습니다. [김한나 / 부산교사노조 위원장]...
# --------------------------------------------------
# 제목: 서울교육감 "학생들 언제까지 '1점 더 받는 교육' 받아야 하나"[인터뷰]
# 본문: 지난 13일 정 교육감이 제안한 10대 공약을 보면 ▲기초학력 보장 ▲특수교육·다문화 학생 맞춤 지원 확대 ▲학생·교원 마음 건강 지원 강화 ▲교권보호 강화 ▲교육공무원 정치적 기본권 보장 ▲적정 교원 정원 재설계...
# --------------------------------------------------
# 제목: [윤경민 칼럼] 학생이 교사 폭행하는 시대 ... 교권침해 이대로 방치할...
# 본문: 새내기 교사가 학부모의 지속적인 민원과 압박으로 인해 스스로 극단적 선택을 한 사건은 교권 침해의 심각성을 환기시켰고 교사들이 촛불을 들고 거리로 나가게 만들었다. 하지만 지금도 교권 침해 사건은 끊임없이...
# --------------------------------------------------
# 제목: 경기도의회 교육행정위원회 민주당 의원들, 교육계 이재명 후보 지지세...
# 본문: 또 "학교 안팎에서 교권이 무너지고 학교 폭력이 빈번하게 일어나는 등 구성원간 갈등이 커지면서 교육공동체 붕괴를 우려하는 목소리가 커지고 있다"면서 "이재명 후보는 국민이 안전하게 살아갈 수 있는 사회, 아이들이...
# --------------------------------------------------
# 제목: 2025 일산 파주 지역 대입 수시 합격자 인터뷰 - 연세대학교 아동가족학...
# 본문: 원래 저는 교사를 목표로 했었는데, 교권추락과 같은 이슈를 접하면서 희망진로가 흔들리기도 했습니다. 그런데 교학상장을 통해 제가 누군가에게 지식을 전달해주고 그 누군가가 성장해가는 모습을 보는 것이 제게 큰...
# --------------------------------------------------
# 제목: [아침논단]새 정부에 바란다
# 본문: 두 번째는 교권 관련법의 입법화와 교사들의 처우다. 교권보호 5법인 교육기본권, 유아교육법, 초중등교육법, 교원지위법, 아동학대처벌법이 도입됐지만 현장은 여전히 교사에게 폭언과 폭행, 욕설, 악성 민원, 무분별한...
# --------------------------------------------------
# 제목: 기억하고 싶지 않던 80년대 민주화운동, 이젠 사랑하게 될 것 같다
# 본문: '고운'은 사라지고 전교조만 남았으나 지금 사회는 '학생의 인권'과 '교권'의 대립이라는 허구적인 대립을 만들어서 학생들의 주체성을 훼손한다. 여전히 학생은 미숙한 존재이고 통제되어야 할 대상으로 간주된다....
# --------------------------------------------------
# 제목: 고맙습니다 대신
# 본문: 기념해도 교권 추락을 막기에는 역부족이다. 실제로 학생에게 휴대폰 사용을 지도하다가 폭언을 들은 교사가 34%가 넘는다는 교총의 조사에서 보듯이, 스승의 날 제정 44년이 지난 지금 교권 추락을 호소하는 교사는 점점...
# --------------------------------------------------
# 제목: "대입제도 공정성 확보… 가르칠 권리 위한 교원 보호책 절실" [차기 정...
# 본문: 김문수 국민의힘 후보는 유아 무상 교육 확대, 교원 법적 소송 지원 등 교권 및 안전 관련 요구를 반영했다. 이준석 개혁신당 후보는 교권 보호 강화를 위한 소송 책임 명확화, 허위 신고 처벌 등을 공약으로 제시했다....
# --------------------------------------------------
# 제목: 청도 풍각중, 교권보호 주간 운영
# 본문: 이 기간 동안 학교는 봉사동아리 화분심기, 삼행시 짓기, 학부모 대상 교권존중 교육, 교권보호 학생 교육, 교직원 연수 등 다양한 프로그램을 운영하며 학부모·교사·학생이 함께하는 교권 존중 문화 조성에 힘썼다. 특히...
# --------------------------------------------------
# 제목: [대선 공약 톺아보기] 〈10〉교육·인재양성
# 본문: # 6·3 조기대선에 나선 주요 후보들은 교육 공약을 통해 교권 강화, 사교육 부담 완화 등의 의제에서... 이준석 “교권 강화…교육과 보육 분리” 이재명 후보는 교사의 정치활동 자유를 내세웠다. 이 후보는 자신의...
# --------------------------------------------------
# 제목: 제천중학교, 교육 3주체가 함께한 '아침맞이 캠페인'
# 본문: 교권 존중과 상호 배려 문화 확산 위한 따뜻한 아침 인사 ［충북일보］ 제천중학교가 지난 15일 스승의 날을... 이번 행사는 교육활동(교권) 보호의 필요성과 의미를 되새기며 교사와 학생, 학부모 간의 신뢰와 소통을...
# --------------------------------------------------
# 제목: 제44회 스승의 날 기념식 ...세종교총회장기 교직원배구대회 성황
# 본문: 더불어 "세종교총은 앞으로도 현장의 목소리가 교육정책에 반영될 수 있도록 노력하고, 교육공동체 내 갈등 해결과 교권 회복을 위해 최선을 다하겠다"고 밝혔다. 이번 기념식과 배구대회는 스승의 날의 의미를 되새기고...
# --------------------------------------------------
# 제목: 수시로 문자? 교권침해…디지털 시대 교권 위협[별별법]
# 본문: “제가 선생님한테 할 말이 많아서 수시로 문자 메시지를 보냈는데, 이것도 교권 침해 행위인가요?” 스마트폰이 일상화된 디지털 시대, 교육 현장에서는 새로운 형태의 교권침해가 등장하고 있다. 문자메시지, SNS, 몰래...
# --------------------------------------------------
# 제목: "잘못한 학생에 '반성' 가르칠 수 없는 현실"···3인 사제지간 교사들...
# 본문: 교권 추락 속에 지난 한 해에만 9,194명의 교사가 정년이 되기 전 사표를 쓰고 학교를 떠났다. 역대 가장 많은 수다. 33년 차인 심 교사는 교원의 자율성이 점점 사라지면서 무력감이 커진 게 가장 큰 문제라고 지적했다. 그는...
# --------------------------------------------------
# 제목: 이재명 “서울대 10개 만들기” 김문수 “서울대·지방대 공동학위 수여...
# 본문: ‘교권 보호’ 대책이 필요하다는 인식엔 세 후보가 한목소리를 냈다. 李 “지방국립대를 서울대 수준으로”... 교권 보호엔 李·金·李 ‘한 목소리’ 학부모 민원에 시달리던 교사가 숨진 ‘서이초 사태’ 재발을 막기...
# --------------------------------------------------
# 제목: 시민단체 "차별금지법 실체 널리 알려야"
# 본문: 결국 좌파식 '사회변혁'을 위해 다음 세대를 희생시키는 성혁명이나 다름 없습니다.셋째, 좌파 정책은 교권을 붕괴시키고 부모의 권리를 짓밟습니다.오늘날 교사들은 포괄적 성교육의 부작용으로부터 학생들을 보호할 수...
# --------------------------------------------------
# 제목: "담임 몰아내자"…'아이혁신당' 만들어 교사 쫓아낸 초등생들
# 본문: 이후 지역 교권보호위원회는 지난해 9월 A씨를 다른 학교로 발령했다. A씨는 "허위 민원을 낸 학부모나 학생에게서는 어떤 사과도 못 받았다"며 "요즘 '실눈 뜨고 교육하자'는 자조 섞인 말이 교사들 사이에서 나올 정도다....
# --------------------------------------------------
# 제목: "담임 몰아내자"…'아이혁신당' 만들어 담임 내쫓은 초등생들
# 본문: 6학년 학생이 담임 교사를 몰아내기 위해 사조직을 만들어 허위 소문을 퍼뜨리는 등 교권이 점점 더... 이후 지역 교권보호위원회는 A씨를 지난해 9월 다른 학교로 발령했고, 현재 A씨는 이 학교에서 근무하고 있다. 해당...
# --------------------------------------------------
# 제목: 야단쳤다고 아동학대 신고…교권의 '모호한 경계'[별별법]
# 본문: 땅에 떨어진 교권이 이 현상의 주요 원인으로 지목된다. 교사들은 학생 지도 과정에서 아동학대 신고에 시달리며 교권과 교육 활동에 심각한 타격을 받고 있다. 2023년 7월 서울 서초의 한 초등학교 교사가 극단적 선택을 한...
# --------------------------------------------------
# 제목: 전북교육청 변호사협의회, '교육감 방탄용'이라면 해체하는 게 낫다
# 본문: 교권 침해로부터 안전하게 보호받지 못하고 있다는 교사들의 응답이 절반을 훨씬 넘는다는 교원단체들의... 전위부대", "교권 챙기랬더니 교육감 방탄 역할", "입틀막" 등의 비판과 비난이 쏟아졌다. "서거석 교육감의 개인...
# --------------------------------------------------
# 제목: '야구 유세복·큰절 올린' 김문수…"민생·경제·안보 대통령되겠다"
# 본문: 선거운동 나흘째인 15일에는 신도림역에서 첫 서울 출근길 유세에 나선 후 스승의 날을 맞아 교권 강화 공약을 발표했다. 빨간색 유니폼 유세복을 입은 김 후보는 신도림역 1번 출구에서 출근하는 시민들과 함께 악수와...
# --------------------------------------------------
# 제목: '잘사니즘'·'3·3·3 청년주택'·'리쇼어링'…대선 후보들, 정책 경쟁 본...
# 본문: 교권 침해를 방지하기 위한 교사 소송 국가책임제와 허위신고에 대한 무고죄 처벌 강화 및 학생생활지원관 도입 등 교권 보호 방안도 마련했다. 이처럼 후보들이 다양한 분야에서 구체적인 공약을 제시하며 유권자들의...
# --------------------------------------------------
# 제목: 대선후보들, 저출산·사교육비 해법은?…교육 공약 공개
# 본문: 17일 교육계에 따르면 주요 대선 후보가 제시한 공약 중 무상 교육 확대, 교권 보호, 돌봄 사업 강화 등에서는 공통적인 의견을 보였다. 제21대 대통령 선거 공식 선거운동이 시작된 12일 오후 서울 관악구에 이재명...
# --------------------------------------------------
# 제목: 유보통합·교권보호 '한목소리'…정치활동 보장·교육감 직선제 폐지 '눈...
# 본문: 21대 대선 주요 후보들은 유보통합(유치원과 보육서비스의 통합)과 교권 강화를 위한 체계 확립에 한목소리를... '교권 보호' 강조…행정업무 감축·법률 지원 강화 두 후보는 교육계에서 요구하는 '교권 보호'를 위해서도...
# --------------------------------------------------
# 제목: 이재명은 사립대 반발, 김문수는 서울대 반발 나온다 [대학서열 완화 공...
# 본문: 개혁신당 이준석 후보는 교권 강화를 강조했다. 이 후보는 교사 소송 국가책임제 도입 및 전담 변호사 배치, 교사에 대한 허위신고 무고 처벌 강화, (문제행동 학생을 위한) 학습지도실·학생생활지원관 제도 도입, (학생의...
# --------------------------------------------------
# 제목: 이재명·김문수 "대학 서열 허물 것"…재원·구성원 반발 과제
# 본문: 이준석 개혁신당 후보는 교권 강화를 강조했다. 이 후보는 교사 소송 국가책임제 도입 및 전담 변호사 배치, 교사에 대한 허위신고 무고 처벌 강화, (문제 행동 학생을 위한) 학습지도실과 학생생활지원관 제도 도입 등을...
# --------------------------------------------------
# 제목: [위클립] 5월 3주
# 본문: 교사노조연맹은 이번 실태조사가 "단순히 시도교육청에서 보내온 통계에 의존해 수치의 변화를 분석하는 것에 그쳐 현장의 문제를 반영하기 어렵다"며 "교육활동 보호에 관한 제도의 현장 안착을 위해서는 교사의 교권...
# --------------------------------------------------
# 제목: 교권침해 무기력한 대한민국…해외선 '물리력' '구금권'까지
# 본문: 교권 침해로 의욕·사명감 상실…'교직 포기' 교사 증가 미 루이지애나주 '구금권' 영국은 '물리력 사용' 가능 최근 서울 한 고등학교에서 수업 중 학생이 교사를 폭행한 사실이 알려지면서 교권 침해가 심각한 사회...
# --------------------------------------------------
# 제목: "담임 싫어"…'아이혁신당' 만들어 담임 몰아낸 초등생
# 본문: 이후 교권보호위원회는 지난해 9월 A씨를 다른 학교로 발령했다. 그는 이 일로 신체적·물질적 피해가 컸지만 아직까지 학생과 학부모들에게 제대로 된 사과도 못 받았다고 한다. A씨는 "요즘 선생님들 사이에 실눈 뜨고...
# --------------------------------------------------
# 제목: 경남 지난해 교보위 개최 비수도권 중 최다
# 본문: 백승아 의원, 교육활동 침해현황 자료 공개 전국 4199건 중 경남 282건…경기·서울 뒤 지난 한 해 동안 경남지역에서 개최된 교권보호위원회(이하 교보위) 건수가 비수도권 지역 중 가장 많았던 것으로 나타났다. 국회...
# --------------------------------------------------
# 제목: [교사의 눈] "스승 존중 않는 사회…교사 스스로 노래합니다"
# 본문: 네 정말 요즘에 교권 추락 문제라든지 또 여기에 비례해서 선생님들의 사기가 떨어지는 부분 너무나 심각하지 않습니까? 이 노래에 담아내고 싶었던 메시지도 있으셨을 것 같아요. 네 들꽃처럼 피고 싶어는 교사라는...
# --------------------------------------------------
# 제목: '아이 혁신당' 조직해 담임 내쫓으려 한 초등생들… "흉기 휘두르겠다"...
# 본문: '사건반장'에서는 교권이 점점 더 추락하는 듯한 현실을 보여주는 한 교사의 제보가 전해졌다. 15일 방송된... 이후 지역 교권보호위원회는 제보자를 지난해 9월 다른 학교로 발령했고, 현재 제보자는 해당 학교에서 교직을...
# --------------------------------------------------
# 제목: 경상북도교육청연구원, ‘2025년 교육정책 현장 연구 중간 보고회’ 열...
# 본문: 주요 연구과제로는 IB MYP의 경북교육 적용 방안 연구, 진로체험 프로그램 운영 실태 및 효과성 분석을 통한 중학교 진로체험 모델 연구, 마음성장 교재를 활용한 사회정서학습 활성화 연구 , 교원의 교권 및 교원 관련...
# --------------------------------------------------
# 제목: 교육활동 침해 여전…교보위 4천199건 개최
# 본문: 국회 교육위원회 백승아 의원이 공개한 교육활동 침해 현황 자료를 보면 지난해 교권보호위원회가 전국적으로 4천199건 개최됐습니다. 지역별로는 학생 수가 가장 많은 경기도가 1천54건으로 가장 많았고 대구는...
# --------------------------------------------------
# 제목: 이재명 교육캠프, 전직 부총리·교육감 총출동… 윤곽 드러낸 미래교육...
# 본문: 교권보호 등 교사들의 권익신장과 교육활동 침해 예방 대책을 마련하는 교권특위는 김성근 전 교육부 학교혁신지원실장이 위원장이다. 가장 눈에 띄는 건 교육부 개혁 특위다. 이 자리엔 김규태 전 서울시 부교육감(현...
# --------------------------------------------------
# 제목: [위클리인천]"교육의 시작과 끝은 교사… 도성훈, 현장 지원 '강화'
# 본문: 학교지원단의 역할을 더 확대해 교무학사업무 지원은 물론 업 무경감을 위한 과제를 계속 발굴해 갈 것이며, ○ 교육감 직속인 교육활동보호담당관이 교권 보호에 앞장설 것임 - 무엇보다 다양한 소통 창구를 통해...
# --------------------------------------------------
# 제목: [스승의날] 교사들 "교육보다 신고 걱정…교단 설 용기 잃었다"
# 본문: 서울 서이초등학교 교사 사망 사건을 계기로 이른바 '교권 보호 5법'이 마련됐습니다. 하지만 현장에서는... 그 이유로는 전체의 77.5%가 '교권 침해와 과도한 민원'을 꼽았습니다. 학생에게 교권 침해를 당한 적이 있다는...
# --------------------------------------------------
# 제목: "우리 아이랑 '기운합' 맞을까요?"... 5만원 주고 담임·자녀 '궁합' 보는...
# 본문: 선생님이 수용이 크지 않고 잣대가 강하다"는 식의 관상 풀이를 내놓는다.이는 교권추락 문제를 여실히... 이직이나 사직을 고민하는 이유(복수 응답 가능)로는 '교권 침해 및 과도한 민원'이 77.5%로 1순위를 기록했고...
# --------------------------------------------------
# 제목: 경북도교육청연구원, 교육정책 현장 연구 중간 보고회 개최
# 본문: 주요 연구과제로는 △IB MYP의 경북교육 적용 방안 연구 △진로체험 프로그램 운영 실태 및 효과성 분석을 통한 중학교 진로체험 모델 연구 △마음성장 교재를 활용한 사회정서학습 활성화 연구 △교원의 교권 및 교원...
# --------------------------------------------------
# 제목: [금주의 군포시] 인구문제 인식개선 릴레이 캠페인 동참 外
# 본문: 군포의왕교육지원청 교권보호지원센터와 함께 '교육활동 보호 집중구간 지역연계활동 캠페인'을 실시했다. 사진=군포시청 군포시정신건강복지센터는 지난 5월12일부터 14일까지 군포의왕교육지원청 교권보호지원센터와...
# --------------------------------------------------
# 제목: 제천중학교, 교육 3주체가 참여한 교육활동보호 및 아침 맞이 등교 캠페...
# 본문: 제천중학교(교장 조봉주)는 지난 5월 15일 아침, 학교 교육 3주체가 참여하는 교육활동(교권)보호 및 아침 맞이 등교 캠페인을 실시하였다. 제천중학교 교육 3주체는 스승의 날을 맞이하여 교육활동(교권)보호의 중요성을...
# --------------------------------------------------
# 제목: 경주교육지원청, 교육활동보호주간 캠페인 실시
# 본문: ‘교육활동보호주간’은 스승의 날이 포함된 5월 셋째 주를 중심으로 학교, 가정, 지역사회와 함께하는 교권 존중 실천 문화를 확산하는데 그 취지가 있다. 이번 캠페인은 학교 구성원 모두의 존중과 공감의 문화를...
# --------------------------------------------------
# 제목: [단독]민주 선대위, 후보 직속 ‘미래교육자치위원회’ 출범
# 본문: 특위는 AI교육대책특위, 대학교육특위, 미래학교교육특위, 지방교육소멸대책특위, 평생교육특위, 문예체교육특위, 입시 및 사교육대책특위, 교육부개혁특위, 학생건강안전특위, 교권보호특위, 학부모소통특위...
# --------------------------------------------------
# 제목: 울산청소년꿈키움센터, 울산 강남·북 교육지원청 장학관 초청 정책 설...
# 본문: 및 교권침해 가해 학생의 비행청소년 유입을 사전에 차단하기 위한 협조 방안을 구체화하기 위해서다. 정책설명회에 참석한 장학관, 장학사 및 Wee센터장 등은 교육 현장에서 발생하는 다양한 형태의 학교폭력과 교권침해...
# --------------------------------------------------
# 제목: "선생님 내쫓자" 조직 만들어 학대 민원…초등생에 당한 교사 '분통'
# 본문: 초등학생들이 담임 교사를 몰아내기 위해 조직을 만들어 허위 소문을 퍼뜨리는 등 교권이 추락하는 현실을... 이후 지역 교권보호위원회는 A씨를 지난해 9월 다른 학교로 발령했고, 현재 A씨는 이 학교에서 근무하고 있다....
# --------------------------------------------------
# 제목: 강경숙 의원 "이재명 후보 교육공약 적극 지지"
# 본문: 민주·인권·환경·역사교육 등 활성화 △ (고등교육 혁신) 서울대 10개 만들기 △ (직업·평생교육 확대) 직업교육 연계 강화 및 고졸 후학습자 국가장학금 확대 △ (교권 보호 안착) 교원 마음돌봄 휴가 및 정치기본권 보장
# --------------------------------------------------
# 제목: 대선 후보 3인 '교권 보호' 한 목소리...교육개혁 공약은 부실
# 본문: 인더스트리뉴스 김희선 기자  이재명 더불어민주당, 김문수 국민의힘, 이준석 개혁신당 후보가 공통적으로 '교권 보호'를 중심으로 한 교육 공약을 전면 내세웠다. '서이초 사건'으로 교권 추락이 알려지면서 사회적 관심이...
# --------------------------------------------------
# 제목: 5월의 기념일들, 노동절부터 부부의 날까지 [말록 홈즈]
# 본문: 요즘 교권 추락에 대해 모든 국민이 걱정하고 있는데요. 스승의 그림자도 밟지 않는다는 말이 무색해졌습니다. 사실 그 표현은 좀 깊이 생각해 볼 말입니다. 당나라 승려 도선이 쓴 ‘교계율의’에 처음 나온...
# --------------------------------------------------
# 제목: 박 지사 경남의 번영, 스승이 계셨기에 가능
# 본문: 박 지사는 또 "안타깝게도 교육 현장 곳곳에서 교육의 본질이 ′배움과 성장′이 아닌 ′지식의 전달′로 호도되고, 마땅히 존중받아야 할 교권이 흔들리고 있다"며"선생님들이 쌓아 올린 튼튼한 교육적 토대 위에 경남의...
# --------------------------------------------------
# 제목: 이재명, "유아·초등교육의 국가 책임을 강화할 것... K-교육강국 만들...
# 본문: 등 교권 보호 제도도 뿌리내리겠다고 밝혔다. 끝으로 이 후보는 "국가가 보장하고 선생님이 교육에 전념해... 여덟째, 교권 보호 제도를 학교 현장에 뿌리내리겠습니다. 선생님이 행복해야 아이들도 행복합니다. 선생님이...
# --------------------------------------------------
# 제목: 대선 후 법조계 제도 변화 예고
# 본문: 이 후보는 또 교권 보호를 위한 ‘교사 소송 국가책임제’ 도입을 주요 공약으로 발표했다. 교사가 직무 관련 민·형사 소송에 휘말릴 경우 교육청이 직접 소송을 대리하고 시도교육청에 전담 변호사를 배치해 수사와 재판...
# --------------------------------------------------
# 제목: 교권침해 계속, 젊은 교사들이 떠난다
# 본문: 서울 서이초 사건 등 교권 침해 논란을 빚은 일들이 많았지만 상황은 나아지지 않고 있다. 이에 따라 젊은... 교육부가 최근 발표한 2024학년도 교육활동 침해 실태 조사를 보면 초등학교 교권 침해로 열린 교권보호위원회...
# --------------------------------------------------
# 제목: '대선 후보' 이재명·김문수·이준석 교육 공약…"교권 강화" 한목소리
# 본문: 이들 세 후보는 모두 ‘교권 보호’의 필요성에 공감을 표하며 교사 지원정책들을 각자 내놓기도 했다. 다만... 아울러 교권 보호를 위해 불필요한 행정업무는 줄이고 민원 처리 시스템을 더욱 체계화하겠다고 약속했다....
# --------------------------------------------------
# 제목: 김문수 "만 3~5세 무상교육·보육 추진... 유치원·어린이집 간 정부 예...
# 본문: 이번 교육공약에는 교권 강화를 위한 지원방안도 담겨 있다. 김 후보는 교사가 아동학대로 신고돼 수시 진행 시, 교육감이 정당한 생활지도의 의견을 제출한 경우에 한해 불송치할 수 있도록 제도 개선을 추진한다. 이와...
# --------------------------------------------------
# 제목: [뉴스포커스] 대선 D-18 '전국 유세 행보'…尹 탈당론 확산
# 본문: 초등교사협회 간담회에서 교사 소송 국가 책임제, 교사에 대한 허위 신고 및 무고 처벌 강화, 교육 서비스와 민원 응대 분리 등 교권 보호 공약을 내놨는데요. 이 후보의 교권 살리기 행보에 대한 평가도 부탁드립니다....
# --------------------------------------------------
# 제목: ‘생명의 소중함, 스승의 사랑으로’ 캠페인
# 본문: 남윤제 회장은 “단 한 명의 아이도 포기하지 않는 세종교육을 함께 만들어가자”며 “세종교총은 현장 목소리가 교육 정책에 반영되도록 노력하고, 교육공동체 간 갈등 해결과 교권 회복을 위해 최선을 다하겠다”고...
# --------------------------------------------------
# 제목: 교사에 도발하고 녹음해 아동학대 누명…'아이혁신당' 만들어 담임 괴롭...
# 본문: 지난 15일 JTBC '사건반장'에서는 제44회 스승의 날을 맞은 가운데 교권이 점점 더 추락하는 현실을 보여주는... 이후 지역 교권보호위원회는 A 씨를 지난해 9월 다른 학교로 발령했고, 현재 A 씨는 이 학교에서 교직을...
# --------------------------------------------------
# 제목: 경남교총 ‘같이·가치데이’ 행사 열어
# 본문: ‘아이들의 미래, 다시 일어나는 선생님!’이라는 슬로건 아래, 교권 의미와 교직 가치를 재조명하고, 존중과 협력이 살아 있는 교육공동체 문화 조성을 위해 진행됐다. 이날 행사에는 교원 대상 교육공로상 수여식과...
# --------------------------------------------------
# 제목: 이준석 “교사 소송 국가책임제” 교육계 표심 공략…권영국 “기후정...
# 본문: 교권 보호 공약을 내세우며 교육계 표심을 공략했습니다. 민주노동당 권영국 후보는 '기후 정의'를 강조하며... 등 교권 보호 공약을 내세웠습니다. [이준석/개혁신당 대선 후보 : "전문성 가진 변호사를 임용해서 소송을...
# --------------------------------------------------
# 제목: 아산성심학교, 교권 보호 캠페인 및 스승의 날 행사 개최
# 본문: 아산성심학교(교장 백승례)는 지난 14~15일 스승 존중·제자 사랑 교권 보호 캠페인 및 스승의 날 기념 행사를 실시했다. 스승 존중·제자 사랑 교권 보호 캠페인 및 스승의 날 기념 행사 기념행사는 존중과 배려, 서로...
# --------------------------------------------------
# '교권_news.xlsx' 파일에 저장되었습니다.
# /tmp/ipykernel_48093/386099584.py:19: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   clean_content = BeautifulSoup(content, "html.parser").text

# %% [markdown]
# ## 7. 판다스를 활용한 데이터 분석 (선택 사항)
#
# 저장된 데이터를 판다스 데이터프레임으로 변환하여 추가 분석을 수행할 수 있습니다. 판다스(pandas)는 데이터 분석과 조작을 위한 강력한 파이썬 라이브러리로, 다양한 형태의 데이터를 효과적으로 다룰 수 있게 해줍니다.
#
# ### 판다스 데이터프레임의 장점
# - 행과 열 구조로 데이터를 직관적으로 표현
# - 다양한 데이터 소스에서 데이터 로드 가능 (CSV, Excel, SQL 등)
# - 강력한 필터링, 그룹화, 집계 기능 제공
# - 시각화 도구와의 손쉬운 연계
#
# ### 추가 분석 가능성
# 1. **텍스트 분석**: 뉴스 본문에 자주 등장하는 키워드 분석
# 2. **감정 분석**: 뉴스 기사의 긍정/부정 분위기 파악
# 3. **기사 분류**: 주제에 따른 기사 자동 분류 시스템 구축
# 4. **트렌드 분석**: 시간에 따른 키워드 변화 추적
#
# 다음 코드에서는 수집한 뉴스 데이터를 판다스 데이터프레임으로 변환하고, 필요에 따라 CSV 파일로 저장하는 방법을 보여줍니다.

# %%
# 판다스 데이터프레임으로 변환
if response.status_code == 200 and 'items' in news_data:
    # 데이터 준비
    titles = []
    contents = []
    
    for item in news_data['items']:
        title = BeautifulSoup(item['title'].replace("<b>", "").replace("</b>", ""), "html.parser").text
        content = BeautifulSoup(item['description'].replace("<b>", "").replace("</b>", ""), "html.parser").text
        titles.append(title)
        contents.append(content)
    
    # 데이터프레임 생성
    df = pd.DataFrame({
        '제목': titles,
        '본문': contents
    })
    
    # 데이터프레임 출력
    print(df)
    
    # 데이터프레임을 CSV 파일로 저장 (선택 사항)
    # df.to_csv(f"{query}_news.csv", index=False, encoding='utf-8-sig')
    # print(f"'{query}_news.csv' CSV 파일로 저장되었습니다.")
# Out:
#                                            제목  \
# 0                       [채희창칼럼] 날개 없이 추락하는 교권
# 1    이재명 후보 '미래교육자치위원회' 공식 출범… 200명 넘는 전문가 집결
# 2                          [교육논단] 교육 공약을 살펴보다
# 3         [앵커 브리핑] 갈수록 추락하는 교권···공교육 회복은 어떻게?
# 4                         비참한 교권, 누가 이렇게 만들었나
# ..                                        ...
# 95                    ‘생명의 소중함, 스승의 사랑으로’ 캠페인
# 96  교사에 도발하고 녹음해 아동학대 누명…'아이혁신당' 만들어 담임 괴롭...
# 97                       경남교총 ‘같이·가치데이’ 행사 열어
# 98    이준석 “교사 소송 국가책임제” 교육계 표심 공략…권영국 “기후정...
# 99            아산성심학교, 교권 보호 캠페인 및 스승의 날 행사 개최
#
#                                                    본문
# 0   늘어 교권 보호 없인 국가 발전 어려워 지난달 28일 부산의 한 초등학교에서 5학년...
# 1   총장), 교권보호특위(김성근 전 교육부 학교혁신지원실장), 학부모소통특위(김유임 전...
# 2   각종 제도와 장치를 통해서 교권과 학습권을 강화하여 교육 회복을 여는 것. 기초 학...
# 3   2023년 서이초 사건 당시 전국의 교사들이 거리로 나와 ‘공교육 멈춤의 날’ 집회...
# 4   교권은 오랫동안 학생과 학부모, 그리고 그 잘난 정치인들에게 셀 수도 없을 만큼 차...
# ..                                                ...
# 95  남윤제 회장은 “단 한 명의 아이도 포기하지 않는 세종교육을 함께 만들어가자”며 “...
# 96  지난 15일 JTBC '사건반장'에서는 제44회 스승의 날을 맞은 가운데 교권이 점...
# 97  ‘아이들의 미래, 다시 일어나는 선생님!’이라는 슬로건 아래, 교권 의미와 교직 가...
# 98  교권 보호 공약을 내세우며 교육계 표심을 공략했습니다. 민주노동당 권영국 후보는 '...
# 99  아산성심학교(교장 백승례)는 지난 14~15일 스승 존중·제자 사랑 교권 보호 캠페...
#
# [100 rows x 2 columns]
# /tmp/ipykernel_48093/4293506620.py:9: MarkupResemblesLocatorWarning: The input looks more like a filename than markup. You may want to open this file and pass the filehandle into Beautiful Soup.
#   content = BeautifulSoup(item['description'].replace("<b>", "").replace("</b>", ""), "html.parser").text
